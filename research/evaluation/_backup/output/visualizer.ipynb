# %%
import pandas as pd

# %%
retrieval_eval_df = pd.read_csv("./qa_performance_results.csv", encoding="utf-8-sig")

# %%
# 1247th row

row_1247 = retrieval_eval_df.iloc[1248]
print(row_1247)
# Out:
# id                                                                    143
# question                Có các học bổng nào dành riêng cho sinh viên n...
# ground_truth_doc_ids                                                  NaN
# ground_truth_answer     Học bổng SV nghèo vượt khó, SV đạt thành tích ...
# generated_answer        Mình trả lời ngắn gọn nhé.\n\nNgắn gọn: **Hiện...
# method                                                         sem_chunks
# context                 ['Do vậy cơ hội việc làm của các sinh viên là ...
# retrieved_doc_ids                    [56, 8, 20, 56, 23, 9, 31, 8, 7, 24]
# pipeline                                                        basic_rag
# retrieval_mode                                                     hybrid
# Name: 1248, dtype: object
