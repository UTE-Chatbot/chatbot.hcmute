# %%
import pandas as pd

# %%
retrieval_eval_df = pd.read_csv("./retrieval_eval_results.csv", encoding="utf-8-sig")

# %%
retrieval_eval_df.head()
# Out:
#                                             question  top_k  \
# 0  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...      1
# 1  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...      3
# 2  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...      5
# 3  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...     10
# 4  Vị trí Trường Đại học Sư phạm Kỹ thuật TP. Hồ ...      1
#
#                          retrieved_doc_ids  \
# 0                                      [8]
# 1                             [54, 54, 21]
# 2                       [8, 9, 58, 13, 44]
# 3  [19, 25, 46, 10, 8, 58, 20, 39, 15, 29]
# 4                                     [52]
#
#                                          method  \
# 0  naive_chunks_chunk_size_512_chunk_overlap_64
# 1  naive_chunks_chunk_size_512_chunk_overlap_64
# 2  naive_chunks_chunk_size_512_chunk_overlap_64
# 3  naive_chunks_chunk_size_512_chunk_overlap_64
# 4  naive_chunks_chunk_size_512_chunk_overlap_64
#
# ...
