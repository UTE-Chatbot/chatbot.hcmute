# %%
import pandas as pd
df = pd.read_csv("evaluation/output/evaluation_results.csv")
df.head(2)
# Out:
#    qid  pipeline                                           question  \
# 0    0  llm_only  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...
# 1    1  llm_only  Vị trí Trường Đại học Sư phạm Kỹ thuật TP. Hồ ...
#
#                                  ground_truth_answer  \
# 0  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...
# 1  Tọa lạc tại Thành phố Thủ Đức – khu vực cửa ng...
#
#                                     generated_answer context  \
# 0  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...      []
# 1  Vị trí của Trường Đại học Sư phạm Kỹ thuật TP....      []
#
#   retrieved_doc_contents tool_used  latency_s  latency_cached_s
# 0                     []      none     10.945             0.001
# 1                     []      none     23.801             0.001

# %%
context = df.iloc[[15]]["context"]
context
# Out:
# 15    ["GIỚI THIỆU NGÀNH\nNgành Công nghệ Kỹ thuật n...
# Name: context, dtype: object

# %%
context = context.tolist()

# %%
with open("context_test.txt", "w", encoding = 'utf-8') as f:
    for item in context:
        f.write(str(item) + '\n')

# %%
import json
for index, row in df.iterrows():
    contexts = row["context"]
    list_context = json.loads(contexts)
    print(f"list_context length: {len(list_context)}")
# Out:
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 0
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 10
# list_context length: 5
# list_context length: 5
# list_context length: 5
# list_context length: 5
# list_context length: 1
# list_context length: 5
# list_context length: 1
# list_context length: 5
# list_context length: 5
# list_context length: 5
# list_context length: 5
# list_context length: 5
# list_context length: 5
