# %%
from qdrant_client import QdrantClient
from qdrant_client import models

client = QdrantClient(url="http://localhost:6333")

# %%
from qdrant_client import QdrantClient

client = QdrantClient(url="http://localhost:6333")

client.delete(
    collection_name="hcmute_chatbot",
    points_selector=models.PointIdsList(
        points=["b3cf05f8-75a6-48b0-a706-3af8788afae0"],
    ),
)
# Out:
# UpdateResult(operation_id=122, status=<UpdateStatus.COMPLETED: 'completed'>)
